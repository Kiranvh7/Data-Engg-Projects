# %% [markdown]
# Data Structures
#
# 1. Numeric
# 2. Strings
# 3. Lists
# 4. Dictionary
# 5. Sets
# 6. Boolean
# 7. Tuples

# %%
#Numeric
x = 10
y = 12.2

x + y

# %%
y/x

# %%
y * x

# %%
y - x

# %%
#modulus
y % x

# %%
#floor division
y//x

# %%
y/x

# %%
x = -10
y = 12.5

# %%
abs(x)

# %%
x
